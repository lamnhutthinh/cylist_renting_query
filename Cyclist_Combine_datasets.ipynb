# %%
import pandas as pd
import numpy as np
# Out:
# C:\Users\Khang Lam\AppData\Roaming\Python\Python38\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
april2022 = pd.read_csv('E:\Lam Nhut Thinh\Projects\Personal\Coursera\Cyclist\Datasets\Final\\202204-divvy-tripdata.csv')
may2022 = pd.read_csv('E:\Lam Nhut Thinh\Projects\Personal\Coursera\Cyclist\Datasets\Final\\202205-divvy-tripdata.csv')
june2022 = pd.read_csv('E:\Lam Nhut Thinh\Projects\Personal\Coursera\Cyclist\Datasets\Final\\202206-divvy-tripdata.csv')
july2022 = pd.read_csv('E:\Lam Nhut Thinh\Projects\Personal\Coursera\Cyclist\Datasets\Final\\202207-divvy-tripdata.csv')
august2022 = pd.read_csv('E:\Lam Nhut Thinh\Projects\Personal\Coursera\Cyclist\Datasets\Final\\202208-divvy-tripdata.csv')
september2022 = pd.read_csv('E:\Lam Nhut Thinh\Projects\Personal\Coursera\Cyclist\Datasets\Final\\202209-divvy-publictripdata.csv')
october2022 = pd.read_csv('E:\Lam Nhut Thinh\Projects\Personal\Coursera\Cyclist\Datasets\Final\\202210-divvy-tripdata.csv')
november2022 = pd.read_csv('E:\Lam Nhut Thinh\Projects\Personal\Coursera\Cyclist\Datasets\Final\\202211-divvy-tripdata.csv')
december2022 = pd.read_csv('E:\Lam Nhut Thinh\Projects\Personal\Coursera\Cyclist\Datasets\Final\\202212-divvy-tripdata.csv')
january2023 = pd.read_csv('E:\Lam Nhut Thinh\Projects\Personal\Coursera\Cyclist\Datasets\Final\\202301-divvy-tripdata.csv')
february2023 = pd.read_csv('E:\Lam Nhut Thinh\Projects\Personal\Coursera\Cyclist\Datasets\Final\\202302-divvy-tripdata.csv')
march2023 = pd.read_csv('E:\Lam Nhut Thinh\Projects\Personal\Coursera\Cyclist\Datasets\Final\\202303-divvy-tripdata.csv')

# %%
yearly_cylist = [april2022,may2022,june2022,july2022,august2022,september2022,october2022,november2022,december2022,
                january2023,february2023,march2023]
yearly_df = april2022
for i in range(1,len(yearly_cylist)):
    yearly_df = pd.concat([yearly_df,yearly_cylist[i]])
yearly_df
# Out:
#                  ride_id  rideable_type       started_at         ended_at  \
# 0       3564070EEFD12711  electric_bike   4/6/2022 17:42   4/6/2022 17:54
# 1       0B820C7FCF22F489   classic_bike  4/24/2022 19:23  4/24/2022 19:43
# 2       89EEEE32293F07FF   classic_bike  4/20/2022 19:29  4/20/2022 19:35
# 3       84D4751AEB31888D   classic_bike  4/22/2022 21:14  4/22/2022 21:23
# 4       5664BCF0D1DE7A8B  electric_bike  4/16/2022 15:56  4/16/2022 16:02
# ...                  ...            ...              ...              ...
# 258673  BA8B9D1D0AAF5F25  electric_bike    3/8/2023 0:00    3/8/2023 0:06
# 258674  841F8FE05B117E00   classic_bike  3/21/2023 14:24  3/21/2023 14:50
# 258675  25892EF6A0949B97  electric_bike  3/21/2023 16:48  3/21/2023 16:51
# 258676  F6514CD31F2A9723   classic_bike  3/16/2023 20:36  3/16/2023 20:43
# 258677  FEDA9EE828BC56BF  electric_bike  3/27/2023 19:58  3/27/2023 20:03
#
#        ride_length  week_day          start_station_name start_station_id  \
# ...

# %%
yearly_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5803720 entries, 0 to 258677
# Data columns (total 15 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   started_at          object
#  3   ended_at            object
#  4   ride_length         object
#  5   week_day            int64
#  6   start_station_name  object
#  7   start_station_id    object
#  8   end_station_name    object
#  9   end_station_id      object
#  10  start_lat           float64
#  11  start_lng           float64
#  12  end_lat             float64
#  13  end_lng             float64
#  14  member_casual       object
# dtypes: float64(4), int64(1), object(10)
# memory usage: 708.5+ MB

# %%
yearly_df.isnull().sum()
# Out:
# ride_id                    0
# rideable_type              0
# started_at                 0
# ended_at                   0
# ride_length                0
# week_day                   0
# start_station_name    839082
# start_station_id      839214
# end_station_name      896319
# end_station_id        896460
# start_lat                  0
# start_lng                  0
# end_lat                 5855
# end_lng                 5855
# member_casual              0
# dtype: int64

# %%
len(set(yearly_df['start_station_name'].values.tolist()))
# Out:
# 1700

# %%
len(set(yearly_df['end_station_name'].values.tolist()))
# Out:
# 1724

# %%
yearly_df = yearly_df[["ride_id","rideable_type","started_at","ended_at","ride_length","week_day","start_station_name",
                       "end_station_name","member_casual"]]
yearly_df = yearly_df.set_index("ride_id")
yearly_df
# Out:
#                   rideable_type       started_at         ended_at ride_length  \
# ride_id
# 3564070EEFD12711  electric_bike   4/6/2022 17:42   4/6/2022 17:54     0:12:00
# 0B820C7FCF22F489   classic_bike  4/24/2022 19:23  4/24/2022 19:43     0:20:00
# 89EEEE32293F07FF   classic_bike  4/20/2022 19:29  4/20/2022 19:35     0:06:00
# 84D4751AEB31888D   classic_bike  4/22/2022 21:14  4/22/2022 21:23     0:09:00
# 5664BCF0D1DE7A8B  electric_bike  4/16/2022 15:56  4/16/2022 16:02     0:06:00
# ...                         ...              ...              ...         ...
# BA8B9D1D0AAF5F25  electric_bike    3/8/2023 0:00    3/8/2023 0:06     0:06:23
# 841F8FE05B117E00   classic_bike  3/21/2023 14:24  3/21/2023 14:50     0:26:03
# 25892EF6A0949B97  electric_bike  3/21/2023 16:48  3/21/2023 16:51     0:02:35
# F6514CD31F2A9723   classic_bike  3/16/2023 20:36  3/16/2023 20:43     0:07:06
# FEDA9EE828BC56BF  electric_bike  3/27/2023 19:58  3/27/2023 20:03     0:05:44
#
# ...

# %%
#yearly_df.to_csv("yearly_cyclist.csv")
